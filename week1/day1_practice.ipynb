# %% [markdown]
# # ============================================================
# #  DAY 1 — PRACTICE EXERCISES
# #  Attempt each exercise yourself before looking at hints!
# # ============================================================

# %%
# ─────────────────────────────────────────────
# EXERCISE 1: Create a Customer Profile
# ─────────────────────────────────────────────
# Create variables for a customer:
#   - name (string)
#   - age (int)
#   - account_balance (float)
#   - is_premium_member (bool)
#   - last_purchase (set it to None)
#
# Then print a summary using an f-string like:
# "Customer: Alice | Age: 30 | Balance: $1500.75 | Premium: True"

# YOUR CODE HERE:

cust_Name = str(input("Enter Your Name: "))
cust_Age = int(input("Enter your Age: "))
cust_Account_Balance = float(input("Enter your account balance: "))
cust_Is_Premium_Member = bool(input("Are you a premium member: "))
cust_Last_Purchase = None

print(f"Customer: {cust_Name} | Age: {cust_Age} | Balance: ${cust_Account_Balance:.2f} | Premium: {cust_Is_Premium_Member}")
# Out:
# Customer: Alice | Age: 30 | Balance: $1500.75 | Premium: True

# %%
# ─────────────────────────────────────────────
# EXERCISE 2: Type Inspector
# ─────────────────────────────────────────────
# Given these variables, print the type of each one using type()
# AND check using isinstance() if it is the correct type

data = [42, 3.14, "analyst", True, None]

for i in data:
    print(f"Value: {i} | Type: {type(i)})")
# Out:
# Value: 42 | Type: <class 'int'>)
# Value: 3.14 | Type: <class 'float'>)
# Value: analyst | Type: <class 'str'>)
# Value: True | Type: <class 'bool'>)
# Value: None | Type: <class 'NoneType'>)

# %%
# EXERCISE 3: Data Cleaning Simulation
# ─────────────────────────────────────────────
# In real data, numbers often come in as strings.
# Convert these and perform calculations:

units_str = "150"
units = int(units_str)  # Convert to integer
price_str = "29.99"
price = float(price_str)  # Convert to float
discount_str = "0.15"
discount = float(discount_str)  # Convert to float

# 1. Convert all three to the correct numeric types
# 2. Calculate: total = units * price
# 3. Calculate: discounted_total = total - (total * discount)
# 4. Print: "Total: $XXXX.XX | After Discount: $XXXX.XX"

# YOUR CODE HERE:
total = units * price
discounted_total = total - (total * discount)

print(f"Total: ${total} | After Discount: ${discounted_total}")
# Out:
# Total: $4498.5 | After Discount: $3823.725

# %%
# ─────────────────────────────────────────────
# EXERCISE 4: String Operations
# ─────────────────────────────────────────────
# Given this messy customer name from a database:
raw_name = "   john SMITH   "

# 1. Strip whitespace
# 2. Convert to proper title case (John Smith)
# 3. Split into first and last name
# 4. Print: "First: John | Last: Smith"

# YOUR CODE HERE:
clean_name = raw_name.strip().title()
first_name, last_name = clean_name.split()
print(f"First: {first_name} | Last: {last_name}")
# Out:
# First: John | Last: Smith

# %%
# ─────────────────────────────────────────────
# EXERCISE 5: Sales Calculator
# ─────────────────────────────────────────────
# A store has:
#   - product = "Laptop"
#   - original_price = 1200
#   - discount_percent = 20
#   - tax_percent = 8
#   - quantity = 3

# Calculate and print:
#   1. Discount amount
#   2. Price after discount
#   3. Tax amount (on discounted price)
#   4. Final price per unit (after discount + tax)
#   5. Total for all units
#   Format all money values to 2 decimal places using f-strings

# YOUR CODE HERE:
product = "Laptop"
original_price = 1200
discount_percent = 20
tax_percent = 8
quantity = 3                        

discount_amount = (discount_percent / 100) * original_price
price_after_discount = original_price - discount_amount
tax_amount = (tax_percent / 100) * price_after_discount
final_price_per_unit = price_after_discount + tax_amount
total_for_all_units = final_price_per_unit * quantity

print(f"Product: {product}")
print(f"Original Price: ${original_price}")
print(f"Discount Amount: ${discount_amount}")
print(f"Price After Discount: ${price_after_discount}")
print(f"Tax Amount: ${tax_amount}")
print(f"Final Price per Unit: ${final_price_per_unit}")
print(f"Total for {quantity} units: ${total_for_all_units}")
# Out:
# Product: Laptop
# Original Price: $1200
# Discount Amount: $240.0
# Price After Discount: $960.0
# Tax Amount: $76.8
# Final Price per Unit: $1036.8
# Total for 3 units: $3110.3999999999996

# %%
# ─────────────────────────────────────────────
# EXERCISE 6: Eligibility Checker
# ─────────────────────────────────────────────
# Write conditions to check:
# A customer is eligible for a loan if:
#   - age >= 21
#   - income >= 30000
#   - credit_score >= 700
#   - has_existing_loan is False

age = 25
income = 45000
credit_score = 720
has_existing_loan = False

# 1. Create a boolean variable: is_eligible
# 2. Print: "Eligible for loan: True/False"
# 3. BONUS: print WHY they are not eligible if is_eligible is False

# YOUR CODE HERE:
is_eligible = age >= 21 and income >= 30000 and credit_score >= 700 and not has_existing_loan

print(f"Eligible for loan: {is_eligible}")

if not is_eligible:
    if age < 21:
        print("Reason: Age is less than 21")
    if income < 30000:
        print("Reason: Income is less than $30,000")
    if credit_score < 700:
        print("Reason: Credit score is less than 700")
    if has_existing_loan:
        print("Reason: Customer has an existing loan")
# Out:
# Eligible for loan: True

# %%
# ─────────────────────────────────────────────
# EXERCISE 7: Modulo Magic
# ─────────────────────────────────────────────
# Use the modulo operator (%) to:
# 1. Check if 847 is even or odd
# 2. Check if 2025 is a leap year
#    (leap year: divisible by 4, but not 100, UNLESS also divisible by 400)
# 3. Find the remainder when 1000 is divided by 7

year = 2025
number = 847
value = 1000

# YOUR CODE HERE:
# Check if 847 is even or odd
if number % 2 == 0:
    print(f"{number} is even.")
else:
    print(f"{number} is odd.")          

# Check if 2025 is a leap year
if (year % 4 == 0 and year % 100 != 0) or(year % 400 == 0):
     print(f"{year} is a leap year.")      
else:
     print(f"{year} is not a leap year.")   
# Find the remainder when 1000 is divided by 7
remainder = value % 7
print(f"The remainder when {value} is divided by 7 is: {remainder}")
# Out:
# 847 is odd.
# 2025 is not a leap year.
# The remainder when 1000 is divided by 7 is: 6

# %%
# ─────────────────────────────────────────────
# EXERCISE 8: Mini Analytics Report
# ─────────────────────────────────────────────
# Given monthly sales data as strings (as if read from a text file):
jan = "45000"
jan_int = int(jan)  # Convert to integer
feb = "38000"
feb_int = int(feb)  # Convert to integer
mar = "52000"
mar_int = int(mar)  # Convert to integer

# 1. Convert all to integers
# 2. Calculate: total, average, highest month, lowest month
# 3. Print a formatted report:
#    === Q1 Sales Report ===
#    January  : $45,000
#    February : $38,000
#    March    : $52,000
#    ----------------------
#    Total    : $135,000
#    Average  : $45,000
#    Best Month: March

# YOUR CODE HERE:

total = jan_int + feb_int + mar_int
average = total / 3
sales_data = {"January": jan_int, "February": feb_int, "March": mar_int}
best_month = max(sales_data, key=sales_data.get)    

print("=== Q1 Sales Report ===")
print(f"January  : ${jan_int:,}")
print(f"February : ${feb_int:,}")
print(f"March    : ${mar_int:,}")
print("----------------------")
print(f"Total    : ${total:,}")
print(f"Average  : ${average:,.2f}")
print(f"Best Month: {best_month}")
# Out:
# === Q1 Sales Report ===
# January  : $45,000
# February : $38,000
# March    : $52,000
# ----------------------
# Total    : $135,000
# Average  : $45,000.00
# Best Month: March
